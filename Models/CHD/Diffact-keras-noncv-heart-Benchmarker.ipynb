# %%
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential

# %load_ext tensorboard
import datetime

from tensorflow.keras.utils import to_categorical

filename = "../../Datasets/CHD/heart.csv"

df = pd.read_csv(filename)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
initializer0 = keras.initializers.RandomUniform(minval = -2, maxval =2)
initializer1 = keras.initializers.RandomUniform(minval = -2, maxval =2)
initializer2 = keras.initializers.RandomUniform(minval = -2, maxval =2)

class Diffact(keras.layers.Layer):
    def __init__(self):
        super(Diffact, self).__init__()
        self.k0 = self.add_weight(name='k0', shape = (), initializer=initializer0, trainable=True)
        self.k1 = self.add_weight(name='k1', shape = (), initializer=initializer1, trainable=True)
        self.k2 = self.add_weight(name='k2', shape = (), initializer=initializer2, trainable=True)
        
    def call(self, inputs):
        return self.k0 + tf.multiply(inputs, self.k1) + tf.multiply(tf.multiply(inputs,inputs), self.k2)
    
from keras import backend as K
class Mish(keras.layers.Layer):
    '''
    Mish Activation Function.
    .. math::
        mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + e^{x}))
    Shape:
        - Input: Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a model.
        - Output: Same shape as the input.
    Examples:
        >>> X_input = Input(input_shape)
        >>> X = Mish()(X_input)
    '''

    def __init__(self, **kwargs):
        super(Mish, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, inputs):
        return inputs * K.tanh(K.softplus(inputs))

    def get_config(self):
        base_config = super(Mish, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def compute_output_shape(self, input_shape):
        return input_shape
# Out:
# Using TensorFlow backend.

# %%
#Change the column names for better understanding
df.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
       'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'target']

# %%
#Finding the shape of the dataframe
df.shape
# Out:
# (303, 14)

# %%
# Describing the Dataframe
df.describe()
# Out:
#               age         sex  chest_pain_type  resting_blood_pressure  \
# count  303.000000  303.000000       303.000000              303.000000
# mean    54.366337    0.683168         0.966997              131.623762
# std      9.082101    0.466011         1.032052               17.538143
# min     29.000000    0.000000         0.000000               94.000000
# 25%     47.500000    0.000000         0.000000              120.000000
# 50%     55.000000    1.000000         1.000000              130.000000
# 75%     61.000000    1.000000         2.000000              140.000000
# max     77.000000    1.000000         3.000000              200.000000
#
#        cholesterol  fasting_blood_sugar    rest_ecg  max_heart_rate_achieved  \
# count   303.000000           303.000000  303.000000               303.000000
# mean    246.264026             0.148515    0.528053               149.646865
# std      51.830751             0.356198    0.525860                22.905161
# min     126.000000             0.000000    0.000000                71.000000
# 25%     211.000000             0.000000    0.000000               133.500000
# 50%     240.000000             0.000000    1.000000               153.000000
# 75%     274.500000             0.000000    1.000000               166.000000
# max     564.000000             1.000000    2.000000               202.000000
#
#        exercise_induced_angina  st_depression    st_slope  num_major_vessels  \
# count               303.000000     303.000000  303.000000         303.000000
# mean                  0.326733       1.039604    1.399340           0.729373
# std                   0.469794       1.161075    0.616226           1.022606
# min                   0.000000       0.000000    0.000000           0.000000
# 25%                   0.000000       0.000000    1.000000           0.000000
# 50%                   0.000000       0.800000    1.000000           0.000000
# 75%                   1.000000       1.600000    2.000000           1.000000
# max                   1.000000       6.200000    2.000000           4.000000
#
#        thalassemia      target
# count   303.000000  303.000000
# mean      2.313531    0.544554
# std       0.612277    0.498835
# min       0.000000    0.000000
# 25%       2.000000    0.000000
# 50%       2.000000    1.000000
# 75%       3.000000    1.000000
# max       3.000000    1.000000

# %%
#Finding information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      303 non-null    int64
#  1   sex                      303 non-null    int64
#  2   chest_pain_type          303 non-null    int64
#  3   resting_blood_pressure   303 non-null    int64
#  4   cholesterol              303 non-null    int64
#  5   fasting_blood_sugar      303 non-null    int64
#  6   rest_ecg                 303 non-null    int64
#  7   max_heart_rate_achieved  303 non-null    int64
#  8   exercise_induced_angina  303 non-null    int64
#  9   st_depression            303 non-null    float64
#  10  st_slope                 303 non-null    int64
#  11  num_major_vessels        303 non-null    int64
#  12  thalassemia              303 non-null    int64
#  13  target                   303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#Finding the missing values. In this dataframe there is no missing value.
df.isnull().sum()
# Out:
# age                        0
# sex                        0
# chest_pain_type            0
# resting_blood_pressure     0
# cholesterol                0
# fasting_blood_sugar        0
# rest_ecg                   0
# max_heart_rate_achieved    0
# exercise_induced_angina    0
# st_depression              0
# st_slope                   0
# num_major_vessels          0
# thalassemia                0
# target                     0
# dtype: int64

# %%
# Select the columns to use for prediction in the neural network
X= df.drop('target',axis=1)
Y=df['target']
print (X.shape, Y.shape, df.columns)
Y=np.array(Y)
Y=to_categorical(Y)
# Out:
# (303, 13) (303,) Index(['age', 'sex', 'chest_pain_type', 'resting_blood_pressure',
#        'cholesterol', 'fasting_blood_sugar', 'rest_ecg',
#        'max_heart_rate_achieved', 'exercise_induced_angina', 'st_depression',
#        'st_slope', 'num_major_vessels', 'thalassemia', 'target'],
#       dtype='object')

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
# split data into train, test
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=39, shuffle=True)
#kipping y since value already 1 or 0
# encoder = LabelEncoder()
# encoder.fit(Y)
# encoded_Y = encoder.transform(Y)

# normalize data
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)
X_test_scaled = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test_scaled)

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print (df.columns)
# Out:
# (212, 13) (212, 2)
# (91, 13) (91, 2)
# Index(['age', 'sex', 'chest_pain_type', 'resting_blood_pressure',
#        'cholesterol', 'fasting_blood_sugar', 'rest_ecg',
#        'max_heart_rate_achieved', 'exercise_induced_angina', 'st_depression',
#        'st_slope', 'num_major_vessels', 'thalassemia', 'target'],
#       dtype='object')

# %%
# create model with fully connected layers with dropout regulation
model = Sequential()
model.add(layers.Dense(25, input_dim=13, activation='relu'))
#diffact = Diffact()
#model.add(Mish())
model.add(layers.Dropout(0.1))
model.add(layers.Dense(2, activation = 'softmax'))
#model.add(diffact)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25)                350
# _________________________________________________________________
# dropout (Dropout)            (None, 25)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 52
# =================================================================
# Total params: 402
# Trainable params: 402
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 5
epochs = 100

model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(amsgrad=True), metrics=["accuracy"])

log_dir = "logs/fit4/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.33 ,callbacks=[tensorboard_callback], verbose=1)
# Out:
# Epoch 1/100
#  1/29 [>.............................] - ETA: 0s - loss: 0.7780 - accuracy: 0.2000WARNING:tensorflow:From C:\Users\shamb\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0200s). Check your callbacks.
# 29/29 [==============================] - 0s 9ms/step - loss: 0.7374 - accuracy: 0.3944 - val_loss: 0.7154 - val_accuracy: 0.4429
# Epoch 2/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5563 - val_loss: 0.6701 - val_accuracy: 0.6000
# Epoch 3/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6490 - accuracy: 0.6620 - val_loss: 0.6355 - val_accuracy: 0.7286
# Epoch 4/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6241 - accuracy: 0.7042 - val_loss: 0.5988 - val_accuracy: 0.7286
# Epoch 5/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5947 - accuracy: 0.7465 - val_loss: 0.5691 - val_accuracy: 0.7286
# Epoch 6/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5763 - accuracy: 0.7676 - val_loss: 0.5447 - val_accuracy: 0.7714
# Epoch 7/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5596 - accuracy: 0.7817 - val_loss: 0.5196 - val_accuracy: 0.8000
# Epoch 8/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5384 - accuracy: 0.7746 - val_loss: 0.5036 - val_accuracy: 0.8000
# Epoch 9/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5093 - accuracy: 0.8310 - val_loss: 0.4857 - val_accuracy: 0.8143
# Epoch 10/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5001 - accuracy: 0.7606 - val_loss: 0.4708 - val_accuracy: 0.8286
# Epoch 11/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4863 - accuracy: 0.8028 - val_loss: 0.4575 - val_accuracy: 0.8286
# Epoch 12/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4701 - accuracy: 0.8028 - val_loss: 0.4495 - val_accuracy: 0.8571
# Epoch 13/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4590 - accuracy: 0.8099 - val_loss: 0.4426 - val_accuracy: 0.8429
# Epoch 14/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.8169 - val_loss: 0.4307 - val_accuracy: 0.8286
# Epoch 15/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8310 - val_loss: 0.4297 - val_accuracy: 0.8429
# Epoch 16/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.8451 - val_loss: 0.4236 - val_accuracy: 0.8571
# Epoch 17/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4414 - accuracy: 0.8099 - val_loss: 0.4200 - val_accuracy: 0.8429
# Epoch 18/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.8310 - val_loss: 0.4139 - val_accuracy: 0.8571
# Epoch 19/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4221 - accuracy: 0.7958 - val_loss: 0.4186 - val_accuracy: 0.8143
# Epoch 20/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4257 - accuracy: 0.8451 - val_loss: 0.4053 - val_accuracy: 0.8571
# Epoch 21/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4021 - accuracy: 0.8099 - val_loss: 0.4065 - val_accuracy: 0.8286
# Epoch 22/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.8380 - val_loss: 0.4010 - val_accuracy: 0.8429
# Epoch 23/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4066 - accuracy: 0.8310 - val_loss: 0.4014 - val_accuracy: 0.8143
# Epoch 24/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4142 - accuracy: 0.8169 - val_loss: 0.3969 - val_accuracy: 0.8429
# Epoch 25/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3929 - accuracy: 0.8239 - val_loss: 0.3973 - val_accuracy: 0.8286
# Epoch 26/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3967 - accuracy: 0.8521 - val_loss: 0.3959 - val_accuracy: 0.8143
# Epoch 27/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3876 - accuracy: 0.8521 - val_loss: 0.3924 - val_accuracy: 0.8429
# Epoch 28/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3916 - accuracy: 0.8310 - val_loss: 0.3947 - val_accuracy: 0.8286
# Epoch 29/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8239 - val_loss: 0.3978 - val_accuracy: 0.8429
# Epoch 30/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3937 - accuracy: 0.8521 - val_loss: 0.3977 - val_accuracy: 0.8429
# Epoch 31/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8521 - val_loss: 0.4007 - val_accuracy: 0.8429
# Epoch 32/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3699 - accuracy: 0.8521 - val_loss: 0.3956 - val_accuracy: 0.8429
# Epoch 33/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3860 - accuracy: 0.8451 - val_loss: 0.4000 - val_accuracy: 0.8429
# Epoch 34/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8592 - val_loss: 0.3976 - val_accuracy: 0.8429
# Epoch 35/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3685 - accuracy: 0.8592 - val_loss: 0.3932 - val_accuracy: 0.8429
# Epoch 36/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8451 - val_loss: 0.3931 - val_accuracy: 0.8714
# Epoch 37/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8521 - val_loss: 0.3943 - val_accuracy: 0.8714
# Epoch 38/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3541 - accuracy: 0.8592 - val_loss: 0.3951 - val_accuracy: 0.8571
# Epoch 39/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8662 - val_loss: 0.4000 - val_accuracy: 0.8714
# Epoch 40/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3721 - accuracy: 0.8592 - val_loss: 0.3972 - val_accuracy: 0.8714
# Epoch 41/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3476 - accuracy: 0.8592 - val_loss: 0.3895 - val_accuracy: 0.8286
# Epoch 42/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3552 - accuracy: 0.8521 - val_loss: 0.3965 - val_accuracy: 0.8714
# Epoch 43/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.8451 - val_loss: 0.3992 - val_accuracy: 0.8714
# Epoch 44/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3531 - accuracy: 0.8592 - val_loss: 0.3981 - val_accuracy: 0.8714
# Epoch 45/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8803 - val_loss: 0.4014 - val_accuracy: 0.8714
# Epoch 46/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.8451 - val_loss: 0.3985 - val_accuracy: 0.8571
# Epoch 47/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3429 - accuracy: 0.8732 - val_loss: 0.4030 - val_accuracy: 0.8571
# Epoch 48/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3463 - accuracy: 0.8662 - val_loss: 0.3962 - val_accuracy: 0.8571
# Epoch 49/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3545 - accuracy: 0.8592 - val_loss: 0.3988 - val_accuracy: 0.8571
# Epoch 50/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8662 - val_loss: 0.3966 - val_accuracy: 0.8714
# Epoch 51/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3417 - accuracy: 0.8732 - val_loss: 0.4024 - val_accuracy: 0.8429
# Epoch 52/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3380 - accuracy: 0.8521 - val_loss: 0.4029 - val_accuracy: 0.8429
# Epoch 53/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.8732 - val_loss: 0.4003 - val_accuracy: 0.8714
# Epoch 54/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8732 - val_loss: 0.4011 - val_accuracy: 0.8571
# Epoch 55/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3351 - accuracy: 0.8521 - val_loss: 0.4030 - val_accuracy: 0.8571
# Epoch 56/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3258 - accuracy: 0.8732 - val_loss: 0.3995 - val_accuracy: 0.8571
# Epoch 57/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3169 - accuracy: 0.8732 - val_loss: 0.4022 - val_accuracy: 0.8571
# Epoch 58/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3182 - accuracy: 0.8732 - val_loss: 0.4045 - val_accuracy: 0.8286
# Epoch 59/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3263 - accuracy: 0.8873 - val_loss: 0.4007 - val_accuracy: 0.8714
# Epoch 60/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3284 - accuracy: 0.8662 - val_loss: 0.4046 - val_accuracy: 0.8571
# Epoch 61/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8592 - val_loss: 0.4059 - val_accuracy: 0.8429
# Epoch 62/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3196 - accuracy: 0.8803 - val_loss: 0.4074 - val_accuracy: 0.8429
# Epoch 63/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3485 - accuracy: 0.8451 - val_loss: 0.4018 - val_accuracy: 0.8429
# Epoch 64/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8662 - val_loss: 0.4017 - val_accuracy: 0.8714
# Epoch 65/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3216 - accuracy: 0.8803 - val_loss: 0.4037 - val_accuracy: 0.8429
# Epoch 66/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3126 - accuracy: 0.9014 - val_loss: 0.4062 - val_accuracy: 0.8429
# Epoch 67/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3119 - accuracy: 0.8662 - val_loss: 0.4031 - val_accuracy: 0.8429
# Epoch 68/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2850 - accuracy: 0.9155 - val_loss: 0.4062 - val_accuracy: 0.8429
# Epoch 69/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3106 - accuracy: 0.8662 - val_loss: 0.4063 - val_accuracy: 0.8429
# Epoch 70/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3290 - accuracy: 0.8732 - val_loss: 0.4011 - val_accuracy: 0.8714
# Epoch 71/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3116 - accuracy: 0.8592 - val_loss: 0.4034 - val_accuracy: 0.8429
# Epoch 72/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2997 - accuracy: 0.8732 - val_loss: 0.4086 - val_accuracy: 0.8429
# Epoch 73/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3212 - accuracy: 0.8732 - val_loss: 0.3995 - val_accuracy: 0.8000
# Epoch 74/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3357 - accuracy: 0.8732 - val_loss: 0.4091 - val_accuracy: 0.8429
# Epoch 75/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.8732 - val_loss: 0.4106 - val_accuracy: 0.8429
# Epoch 76/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3106 - accuracy: 0.8662 - val_loss: 0.4087 - val_accuracy: 0.8429
# Epoch 77/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3084 - accuracy: 0.8803 - val_loss: 0.4096 - val_accuracy: 0.8429
# Epoch 78/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3027 - accuracy: 0.8944 - val_loss: 0.4062 - val_accuracy: 0.8429
# Epoch 79/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3159 - accuracy: 0.8662 - val_loss: 0.4069 - val_accuracy: 0.8429
# Epoch 80/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3008 - accuracy: 0.8803 - val_loss: 0.4087 - val_accuracy: 0.8429
# Epoch 81/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3003 - accuracy: 0.8732 - val_loss: 0.4032 - val_accuracy: 0.8429
# Epoch 82/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.3149 - accuracy: 0.8803 - val_loss: 0.4031 - val_accuracy: 0.8429
# Epoch 83/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2929 - accuracy: 0.8944 - val_loss: 0.4061 - val_accuracy: 0.8429
# Epoch 84/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.8732 - val_loss: 0.4055 - val_accuracy: 0.8429
# Epoch 85/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.8803 - val_loss: 0.4148 - val_accuracy: 0.8286
# Epoch 86/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2838 - accuracy: 0.9085 - val_loss: 0.4110 - val_accuracy: 0.8429
# Epoch 87/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2946 - accuracy: 0.8662 - val_loss: 0.4098 - val_accuracy: 0.8429
# Epoch 88/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2810 - accuracy: 0.8944 - val_loss: 0.4168 - val_accuracy: 0.8286
# Epoch 89/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2841 - accuracy: 0.9014 - val_loss: 0.4198 - val_accuracy: 0.8286
# Epoch 90/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2870 - accuracy: 0.8944 - val_loss: 0.4204 - val_accuracy: 0.8286
# Epoch 91/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2901 - accuracy: 0.8803 - val_loss: 0.4196 - val_accuracy: 0.8286
# Epoch 92/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2881 - accuracy: 0.8732 - val_loss: 0.4217 - val_accuracy: 0.8286
# Epoch 93/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2779 - accuracy: 0.8803 - val_loss: 0.4220 - val_accuracy: 0.8286
# Epoch 94/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2839 - accuracy: 0.8732 - val_loss: 0.4210 - val_accuracy: 0.8286
# Epoch 95/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.8803 - val_loss: 0.4189 - val_accuracy: 0.8286
# Epoch 96/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2964 - accuracy: 0.8873 - val_loss: 0.4212 - val_accuracy: 0.8286
# Epoch 97/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2914 - accuracy: 0.8592 - val_loss: 0.4198 - val_accuracy: 0.8429
# Epoch 98/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2850 - accuracy: 0.8803 - val_loss: 0.4255 - val_accuracy: 0.8286
# Epoch 99/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2789 - accuracy: 0.8873 - val_loss: 0.4271 - val_accuracy: 0.8143
# Epoch 100/100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2746 - accuracy: 0.8944 - val_loss: 0.4253 - val_accuracy: 0.8286

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.36052629351615906
# Test accuracy: 0.8571428656578064

# %%
#print("AF coefficients (weights) {}".format(diffact.get_weights()))

# %%
# %tensorboard --logdir logs/fit4 --port=8042
# Out:
# Reusing TensorBoard on port 8042 (pid 18904), started 0:03:00 ago. (Use '!kill 18904' to kill it.)
#       <iframe id="tensorboard-frame-a97b446153e882f1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a97b446153e882f1");
#           const url = new URL("/", window.location);
#           const port = 8042;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
