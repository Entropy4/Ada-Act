# %%
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from pandas.api.types import CategoricalDtype
import seaborn as sns

# %load_ext tensorboard
import datetime

from tensorflow.keras.utils import to_categorical

filename = "../../Datasets/Seeds/seeds_dataset.txt"

df = pd.read_csv(filename,encoding = 'utf-8',header = None, delimiter='\t')
df.head()
# Out:
#        0      1       2      3      4      5      6  7
# 0  15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2  14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1

# %%
df.columns.tolist()
df.rename(columns = {0:'area',1:'perimeter',2:'compac',3:'ker_len',4:'ker_wid',5:'asym_coeff',6:'ker_grvlen', 7:'class_val'},inplace = True)
df.head(1)
df['class_val'].value_counts()
# Out:
# 3    70
# 2    70
# 1    70
# Name: class_val, dtype: int64

# %%
# Create category types.
#class_type = CategoricalDtype(['Type1','Type2','Type3'], ordered=True)

# Convert all categorical values to category type.
#df.class_val = df.class_val.astype(class_type)

# %%
# Convert categories into integers for each column.
df.class_val=df.class_val.replace({1:0, 2:1, 3:2})

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)
sns.heatmap(df.corr(),annot=True, cmap='rainbow',linewidth=0.5)
plt.title('Correlation matrix');

# %%
# Choose attribute columns and class column.
X=df[df.columns[:-1]]
y=df['class_val']

y = np.array(y)
y = to_categorical(y)
df.head()
# Out:
#     area  perimeter  compac  ker_len  ker_wid  asym_coeff  ker_grvlen  \
# 0  15.26      14.84  0.8710    5.763    3.312       2.221       5.220
# 1  14.88      14.57  0.8811    5.554    3.333       1.018       4.956
# 2  14.29      14.09  0.9050    5.291    3.337       2.699       4.825
# 3  13.84      13.94  0.8955    5.324    3.379       2.259       4.805
# 4  16.14      14.99  0.9034    5.658    3.562       1.355       5.175
#
#    class_val
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
initializer0 = keras.initializers.RandomUniform(minval = 0, maxval =2)
initializer1 = keras.initializers.RandomUniform(minval = -2, maxval =2)
initializer2 = keras.initializers.RandomUniform(minval = -2, maxval =0)

class Diffact(keras.layers.Layer):
    def __init__(self):
        super(Diffact, self).__init__()
        self.k0 = self.add_weight(name='k0', shape = (), initializer=initializer0, trainable=True)
        self.k1 = self.add_weight(name='k1', shape = (), initializer=initializer1, trainable=True)
        self.k2 = self.add_weight(name='k2', shape = (), initializer=initializer2, trainable=True)
        
    def call(self, inputs):
        return self.k0 + tf.multiply(inputs, self.k1) + tf.multiply(tf.multiply(inputs,inputs), self.k2)

from keras import backend as K

class Mish(keras.layers.Layer):
    '''
    Mish Activation Function.
    .. math::
        mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + e^{x}))
    Shape:
        - Input: Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a model.
        - Output: Same shape as the input.
    Examples:
        >>> X_input = Input(input_shape)
        >>> X = Mish()(X_input)
    '''

    def __init__(self, **kwargs):
        super(Mish, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, inputs):
        return inputs * K.tanh(K.softplus(inputs))

    def get_config(self):
        base_config = super(Mish, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def compute_output_shape(self, input_shape):
        return input_shape
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
# split data into train, test
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=69, shuffle=True)
#kipping y since value already 1 or 0
# encoder = LabelEncoder()
# encoder.fit(Y)
# encoded_Y = encoder.transform(Y)
'''
# normalize data
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)
X_test_scaled = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test_scaled)
'''
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print (df.columns)
# Out:
# (189, 7) (189, 3)
# (21, 7) (21, 3)
# Index(['area', 'perimeter', 'compac', 'ker_len', 'ker_wid', 'asym_coeff',
#        'ker_grvlen', 'class_val'],
#       dtype='object')

# %%
# create model with fully connected layers with dropout regulation
model = Sequential()
model.add(layers.Dense(25, input_dim=7, activation='relu'))
#diffact=Diffact()
#model.add(Mish())
model.add(layers.Dropout(0.1))
model.add(layers.Dense(3, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25)                200
# _________________________________________________________________
# dropout (Dropout)            (None, 25)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 78
# =================================================================
# Total params: 278
# Trainable params: 278
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 5
epochs = 100

model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(amsgrad=True), metrics=["accuracy"])

log_dir = "logs/opti/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1 ,callbacks=[tensorboard_callback], verbose=1)
# Out:
# Epoch 1/100
#  1/34 [..............................] - ETA: 0s - loss: 4.9213 - accuracy: 0.2000WARNING:tensorflow:From C:\Users\shamb\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0229s). Check your callbacks.
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8716 - accuracy: 0.3118 - val_loss: 1.8732 - val_accuracy: 0.5789
# Epoch 2/100
# 34/34 [==============================] - 0s 1ms/step - loss: 2.1823 - accuracy: 0.3647 - val_loss: 1.0038 - val_accuracy: 0.4211
# Epoch 3/100
# 34/34 [==============================] - 0s 1ms/step - loss: 1.8402 - accuracy: 0.3118 - val_loss: 0.9217 - val_accuracy: 0.5789
# Epoch 4/100
# 34/34 [==============================] - 0s 997us/step - loss: 1.4006 - accuracy: 0.4765 - val_loss: 0.8673 - val_accuracy: 0.7368
# Epoch 5/100
# 34/34 [==============================] - 0s 997us/step - loss: 1.3073 - accuracy: 0.4765 - val_loss: 0.8616 - val_accuracy: 0.5263
# Epoch 6/100
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1528 - accuracy: 0.5588 - val_loss: 0.8224 - val_accuracy: 0.5789
# Epoch 7/100
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2379 - accuracy: 0.5176 - val_loss: 0.7685 - val_accuracy: 0.7368
# Epoch 8/100
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2076 - accuracy: 0.4824 - val_loss: 0.7855 - val_accuracy: 0.6842
# Epoch 9/100
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0643 - accuracy: 0.5176 - val_loss: 0.7566 - val_accuracy: 0.5263
# Epoch 10/100
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0027 - accuracy: 0.5353 - val_loss: 0.7951 - val_accuracy: 0.5263
# Epoch 11/100
# 34/34 [==============================] - 0s 909us/step - loss: 0.9916 - accuracy: 0.5176 - val_loss: 0.7251 - val_accuracy: 0.6316
# Epoch 12/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.9149 - accuracy: 0.6235 - val_loss: 0.6968 - val_accuracy: 0.6316
# Epoch 13/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.9134 - accuracy: 0.5529 - val_loss: 0.6826 - val_accuracy: 0.9474
# Epoch 14/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.8886 - accuracy: 0.5824 - val_loss: 0.6980 - val_accuracy: 0.5789
# Epoch 15/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.8327 - accuracy: 0.6118 - val_loss: 0.6946 - val_accuracy: 0.8421
# Epoch 16/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.8795 - accuracy: 0.6118 - val_loss: 0.7263 - val_accuracy: 0.5789
# Epoch 17/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7954 - accuracy: 0.6059 - val_loss: 0.6939 - val_accuracy: 0.7895
# Epoch 18/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7745 - accuracy: 0.6176 - val_loss: 0.7123 - val_accuracy: 0.5263
# Epoch 19/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7620 - accuracy: 0.6412 - val_loss: 0.6550 - val_accuracy: 0.5789
# Epoch 20/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.6588 - val_loss: 0.6895 - val_accuracy: 0.7895
# Epoch 21/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7145 - accuracy: 0.6588 - val_loss: 0.6704 - val_accuracy: 0.5789
# Epoch 22/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7115 - accuracy: 0.6529 - val_loss: 0.6690 - val_accuracy: 0.7368
# Epoch 23/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7088 - accuracy: 0.6588 - val_loss: 0.6799 - val_accuracy: 0.6316
# Epoch 24/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6548 - accuracy: 0.7294 - val_loss: 0.6575 - val_accuracy: 0.6316
# Epoch 25/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6521 - accuracy: 0.6588 - val_loss: 0.6925 - val_accuracy: 0.6316
# Epoch 26/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6849 - accuracy: 0.7059 - val_loss: 0.6569 - val_accuracy: 0.7368
# Epoch 27/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.6671 - accuracy: 0.6765 - val_loss: 0.6838 - val_accuracy: 0.5789
# Epoch 28/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6235 - accuracy: 0.7588 - val_loss: 0.6744 - val_accuracy: 0.5789
# Epoch 29/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6322 - accuracy: 0.7176 - val_loss: 0.6362 - val_accuracy: 0.6842
# Epoch 30/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6212 - accuracy: 0.7059 - val_loss: 0.6358 - val_accuracy: 0.8421
# Epoch 31/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5866 - accuracy: 0.8000 - val_loss: 0.6574 - val_accuracy: 0.7368
# Epoch 32/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6235 - accuracy: 0.7059 - val_loss: 0.6361 - val_accuracy: 0.7895
# Epoch 33/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5977 - accuracy: 0.7529 - val_loss: 0.6557 - val_accuracy: 0.6316
# Epoch 34/100
# 34/34 [==============================] - 0s 939us/step - loss: 0.5912 - accuracy: 0.7824 - val_loss: 0.6378 - val_accuracy: 0.6842
# Epoch 35/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5852 - accuracy: 0.7588 - val_loss: 0.6177 - val_accuracy: 0.8421
# Epoch 36/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5945 - accuracy: 0.7529 - val_loss: 0.6297 - val_accuracy: 0.7368
# Epoch 37/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5994 - accuracy: 0.7471 - val_loss: 0.6325 - val_accuracy: 0.7895
# Epoch 38/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.6048 - accuracy: 0.7588 - val_loss: 0.6298 - val_accuracy: 0.7895
# Epoch 39/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5745 - accuracy: 0.7765 - val_loss: 0.5878 - val_accuracy: 0.8421
# Epoch 40/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5569 - accuracy: 0.8412 - val_loss: 0.5924 - val_accuracy: 0.8421
# Epoch 41/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5572 - accuracy: 0.7706 - val_loss: 0.6078 - val_accuracy: 0.7368
# Epoch 42/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5640 - accuracy: 0.8235 - val_loss: 0.6047 - val_accuracy: 0.7895
# Epoch 43/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5637 - accuracy: 0.7941 - val_loss: 0.5981 - val_accuracy: 0.7895
# Epoch 44/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5514 - accuracy: 0.7882 - val_loss: 0.5915 - val_accuracy: 0.7895
# Epoch 45/100
# 34/34 [==============================] - 0s 939us/step - loss: 0.5297 - accuracy: 0.8294 - val_loss: 0.5926 - val_accuracy: 0.7895
# Epoch 46/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5319 - accuracy: 0.8235 - val_loss: 0.6034 - val_accuracy: 0.7895
# Epoch 47/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.5203 - accuracy: 0.8529 - val_loss: 0.5975 - val_accuracy: 0.7895
# Epoch 48/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5184 - accuracy: 0.8118 - val_loss: 0.5569 - val_accuracy: 0.8421
# Epoch 49/100
# 34/34 [==============================] - 0s 980us/step - loss: 0.5674 - accuracy: 0.7706 - val_loss: 0.5797 - val_accuracy: 0.7895
# Epoch 50/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4965 - accuracy: 0.8059 - val_loss: 0.5699 - val_accuracy: 0.7895
# Epoch 51/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4946 - accuracy: 0.8412 - val_loss: 0.5456 - val_accuracy: 0.8947
# Epoch 52/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.5253 - accuracy: 0.8294 - val_loss: 0.5636 - val_accuracy: 0.7895
# Epoch 53/100
# 34/34 [==============================] - 0s 998us/step - loss: 0.5441 - accuracy: 0.8000 - val_loss: 0.5851 - val_accuracy: 0.7895
# Epoch 54/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4922 - accuracy: 0.8294 - val_loss: 0.5514 - val_accuracy: 0.8421
# Epoch 55/100
# 34/34 [==============================] - 0s 939us/step - loss: 0.4821 - accuracy: 0.8706 - val_loss: 0.5569 - val_accuracy: 0.8421
# Epoch 56/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.5065 - accuracy: 0.7706 - val_loss: 0.5685 - val_accuracy: 0.7895
# Epoch 57/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.8824 - val_loss: 0.5252 - val_accuracy: 0.8421
# Epoch 58/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.4684 - accuracy: 0.8412 - val_loss: 0.5408 - val_accuracy: 0.7895
# Epoch 59/100
# 34/34 [==============================] - 0s 939us/step - loss: 0.4834 - accuracy: 0.8471 - val_loss: 0.5322 - val_accuracy: 0.8421
# Epoch 60/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.4527 - accuracy: 0.8294 - val_loss: 0.5324 - val_accuracy: 0.8421
# Epoch 61/100
# 34/34 [==============================] - 0s 909us/step - loss: 0.4980 - accuracy: 0.8235 - val_loss: 0.5294 - val_accuracy: 0.8421
# Epoch 62/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4606 - accuracy: 0.8294 - val_loss: 0.5442 - val_accuracy: 0.8421
# Epoch 63/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.4536 - accuracy: 0.8647 - val_loss: 0.6004 - val_accuracy: 0.6842
# Epoch 64/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.4643 - accuracy: 0.8647 - val_loss: 0.4893 - val_accuracy: 0.8947
# Epoch 65/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.4852 - accuracy: 0.8529 - val_loss: 0.5212 - val_accuracy: 0.7895
# Epoch 66/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4797 - accuracy: 0.8412 - val_loss: 0.5385 - val_accuracy: 0.7895
# Epoch 67/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8765 - val_loss: 0.5343 - val_accuracy: 0.7368
# Epoch 68/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.8471 - val_loss: 0.4995 - val_accuracy: 0.8947
# Epoch 69/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4343 - accuracy: 0.8529 - val_loss: 0.5338 - val_accuracy: 0.7895
# Epoch 70/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4405 - accuracy: 0.8529 - val_loss: 0.5248 - val_accuracy: 0.7895
# Epoch 71/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4619 - accuracy: 0.8412 - val_loss: 0.4823 - val_accuracy: 0.8947
# Epoch 72/100
# 34/34 [==============================] - 0s 992us/step - loss: 0.4353 - accuracy: 0.8647 - val_loss: 0.5295 - val_accuracy: 0.7368
# Epoch 73/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4325 - accuracy: 0.8353 - val_loss: 0.4897 - val_accuracy: 0.7895
# Epoch 74/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4330 - accuracy: 0.8412 - val_loss: 0.4807 - val_accuracy: 0.8421
# Epoch 75/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.4345 - accuracy: 0.8412 - val_loss: 0.4998 - val_accuracy: 0.7895
# Epoch 76/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.4505 - accuracy: 0.8471 - val_loss: 0.5032 - val_accuracy: 0.7368
# Epoch 77/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4396 - accuracy: 0.8529 - val_loss: 0.4694 - val_accuracy: 0.8947
# Epoch 78/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4347 - accuracy: 0.8588 - val_loss: 0.4689 - val_accuracy: 0.8421
# Epoch 79/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.4204 - accuracy: 0.8529 - val_loss: 0.4726 - val_accuracy: 0.8421
# Epoch 80/100
# 34/34 [==============================] - 0s 996us/step - loss: 0.3893 - accuracy: 0.8647 - val_loss: 0.4488 - val_accuracy: 0.8947
# Epoch 81/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4252 - accuracy: 0.8765 - val_loss: 0.4914 - val_accuracy: 0.7895
# Epoch 82/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.8235 - val_loss: 0.4903 - val_accuracy: 0.7895
# Epoch 83/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8647 - val_loss: 0.4571 - val_accuracy: 0.8421
# Epoch 84/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4019 - accuracy: 0.8706 - val_loss: 0.4826 - val_accuracy: 0.7895
# Epoch 85/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3804 - accuracy: 0.8647 - val_loss: 0.4403 - val_accuracy: 0.8947
# Epoch 86/100
# 34/34 [==============================] - 0s 976us/step - loss: 0.4115 - accuracy: 0.8412 - val_loss: 0.4893 - val_accuracy: 0.7895
# Epoch 87/100
# 34/34 [==============================] - 0s 909us/step - loss: 0.3950 - accuracy: 0.8824 - val_loss: 0.4579 - val_accuracy: 0.7895
# Epoch 88/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8294 - val_loss: 0.4665 - val_accuracy: 0.8421
# Epoch 89/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4139 - accuracy: 0.8824 - val_loss: 0.4372 - val_accuracy: 0.8421
# Epoch 90/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3769 - accuracy: 0.8765 - val_loss: 0.4163 - val_accuracy: 0.8947
# Epoch 91/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.3909 - accuracy: 0.8941 - val_loss: 0.4330 - val_accuracy: 0.8947
# Epoch 92/100
# 34/34 [==============================] - 0s 939us/step - loss: 0.3859 - accuracy: 0.8706 - val_loss: 0.4706 - val_accuracy: 0.7895
# Epoch 93/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.3869 - accuracy: 0.8765 - val_loss: 0.4697 - val_accuracy: 0.8421
# Epoch 94/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4084 - accuracy: 0.8588 - val_loss: 0.4042 - val_accuracy: 0.8947
# Epoch 95/100
# 34/34 [==============================] - 0s 968us/step - loss: 0.3692 - accuracy: 0.9000 - val_loss: 0.4417 - val_accuracy: 0.8421
# Epoch 96/100
# 34/34 [==============================] - 0s 997us/step - loss: 0.4174 - accuracy: 0.8588 - val_loss: 0.4454 - val_accuracy: 0.8421
# Epoch 97/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3698 - accuracy: 0.8706 - val_loss: 0.4224 - val_accuracy: 0.8421
# Epoch 98/100
# 34/34 [==============================] - 0s 909us/step - loss: 0.3912 - accuracy: 0.8588 - val_loss: 0.3987 - val_accuracy: 0.8947
# Epoch 99/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4226 - accuracy: 0.8471 - val_loss: 0.4800 - val_accuracy: 0.7895
# Epoch 100/100
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8647 - val_loss: 0.3970 - val_accuracy: 0.8947

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.3676161468029022
# Test accuracy: 0.9523809552192688

# %%
#print("AF coefficients (weights) {}".format(diffact.get_weights()))

# %%
# %tensorboard --logdir logs/opti --port=6008
# Out:
# Reusing TensorBoard on port 6008 (pid 3516), started 0:12:24 ago. (Use '!kill 3516' to kill it.)
#       <iframe id="tensorboard-frame-94166f3273facac8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-94166f3273facac8");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
df.describe()
# Out:
#              area   perimeter      compac     ker_len     ker_wid  asym_coeff  \
# count  210.000000  210.000000  210.000000  210.000000  210.000000  210.000000
# mean    14.847524   14.559286    0.870999    5.628533    3.258605    3.700201
# std      2.909699    1.305959    0.023629    0.443063    0.377714    1.503557
# min     10.590000   12.410000    0.808100    4.899000    2.630000    0.765100
# 25%     12.270000   13.450000    0.856900    5.262250    2.944000    2.561500
# 50%     14.355000   14.320000    0.873450    5.523500    3.237000    3.599000
# 75%     17.305000   15.715000    0.887775    5.979750    3.561750    4.768750
# max     21.180000   17.250000    0.918300    6.675000    4.033000    8.456000
#
#        ker_grvlen   class_val
# count  210.000000  210.000000
# mean     5.408071    1.000000
# std      0.491480    0.818448
# min      4.519000    0.000000
# 25%      5.045000    0.000000
# 50%      5.223000    1.000000
# 75%      5.877000    2.000000
# max      6.550000    2.000000
