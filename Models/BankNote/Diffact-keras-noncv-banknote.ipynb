# %%
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from pandas.api.types import CategoricalDtype
import seaborn as sns

# %load_ext tensorboard
import datetime

from tensorflow.keras.utils import to_categorical

filename = "../../Datasets/BankNote/BankNote_Authentication.csv"

df = pd.read_csv(filename,encoding = 'utf-8')
df.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
#df.columns.tolist()
#df.rename(columns = {0:'var',1:'op_yr',2:'num_axnodes',3:'class_val'},inplace = True)
df.head(1)
df['class'].value_counts()
# Out:
# 0    762
# 1    610
# Name: class, dtype: int64

# %%
# Create category types.
#class_type = CategoricalDtype(['Type1','Type2','Type3'], ordered=True)

# Convert all categorical values to category type.
#df.class_val = df.class_val.astype(class_type)

# %%
# Convert categories into integers for each column.
#df.class_val=df.class_val.replace({1:0, 2:1})

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)
sns.heatmap(df.corr(),annot=True, cmap='rainbow',linewidth=0.5)
plt.title('Correlation matrix');

# %%
# Choose attribute columns and class column.
X=df[df.columns[:-1]]
y=df['class']

y = np.array(y)
y = to_categorical(y)
df.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
#initializer0 = keras.initializers.RandomUniform(minval = -0.005, maxval =0)
#initializer1 = keras.initializers.RandomUniform(minval = -0.005, maxval =0)
#initializer2 = keras.initializers.RandomUniform(minval = 1, maxval =2)

initializer0 = keras.initializers.RandomUniform(minval = 0, maxval =0.005)
initializer1 = keras.initializers.RandomUniform(minval = 0, maxval =0.005)
initializer2 = keras.initializers.RandomUniform(minval = -2, maxval =-1)

class Diffact(keras.layers.Layer):
    def __init__(self):
        super(Diffact, self).__init__()
        self.k0 = self.add_weight(name='k0', shape = (), initializer=initializer0, trainable=True)
        self.k1 = self.add_weight(name='k1', shape = (), initializer=initializer1, trainable=True)
        self.k2 = self.add_weight(name='k2', shape = (), initializer=initializer2, trainable=True)
        
    def call(self, inputs):
        return self.k0 + tf.multiply(inputs, self.k1) + tf.multiply(tf.multiply(inputs,inputs), self.k2)

from keras import backend as K

class Mish(keras.layers.Layer):
    '''
    Mish Activation Function.
    .. math::
        mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + e^{x}))
    Shape:
        - Input: Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a model.
        - Output: Same shape as the input.
    Examples:
        >>> X_input = Input(input_shape)
        >>> X = Mish()(X_input)
    '''

    def __init__(self, **kwargs):
        super(Mish, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, inputs):
        return inputs * K.tanh(K.softplus(inputs))

    def get_config(self):
        base_config = super(Mish, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def compute_output_shape(self, input_shape):
        return input_shape
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
# split data into train, test
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=69, shuffle=True)
#kipping y since value already 1 or 0
# encoder = LabelEncoder()
# encoder.fit(Y)
# encoded_Y = encoder.transform(Y)
'''
# normalize data
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)
X_test_scaled = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test_scaled)
'''
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
print (df.columns)
# Out:
# (1234, 4) (1234, 2)
# (138, 4) (138, 2)
# Index(['variance', 'skewness', 'curtosis', 'entropy', 'class'], dtype='object')

# %%
# create model with fully connected layers with dropout regulation
model = Sequential()
model.add(layers.Dense(10, input_dim=4))
diffact=Diffact()
model.add(diffact)
model.add(layers.Dropout(0.1))
model.add(layers.Dense(2, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                50
# _________________________________________________________________
# diffact (Diffact)            (None, 10)                3
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 5
epochs = 100

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

log_dir = "banklogs/smallk1k0/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1 ,callbacks=[tensorboard_callback], verbose=1)
# Out:
# Epoch 1/100
#   1/222 [..............................] - ETA: 0s - loss: 123.8843 - accuracy: 0.6000WARNING:tensorflow:From C:\Users\shamb\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0249s). Check your callbacks.
# 222/222 [==============================] - 0s 1ms/step - loss: 10.3391 - accuracy: 0.5108 - val_loss: 1.5103 - val_accuracy: 0.6774
# Epoch 2/100
# 222/222 [==============================] - 0s 606us/step - loss: 1.6107 - accuracy: 0.7505 - val_loss: 0.5401 - val_accuracy: 0.8710
# Epoch 3/100
# 222/222 [==============================] - 0s 644us/step - loss: 0.8667 - accuracy: 0.8378 - val_loss: 0.2242 - val_accuracy: 0.9355
# Epoch 4/100
# 222/222 [==============================] - 0s 617us/step - loss: 0.5234 - accuracy: 0.8847 - val_loss: 0.1065 - val_accuracy: 0.9516
# Epoch 5/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.4064 - accuracy: 0.9144 - val_loss: 0.0632 - val_accuracy: 0.9839
# Epoch 6/100
# 222/222 [==============================] - 0s 912us/step - loss: 0.3655 - accuracy: 0.9189 - val_loss: 0.0504 - val_accuracy: 0.9919
# Epoch 7/100
# 222/222 [==============================] - 0s 665us/step - loss: 0.2447 - accuracy: 0.9423 - val_loss: 0.0399 - val_accuracy: 0.9919
# Epoch 8/100
# 222/222 [==============================] - 0s 638us/step - loss: 0.2114 - accuracy: 0.9468 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 9/100
# 222/222 [==============================] - 0s 755us/step - loss: 0.1803 - accuracy: 0.9495 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 10/100
# 222/222 [==============================] - 0s 632us/step - loss: 0.1126 - accuracy: 0.9640 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 11/100
# 222/222 [==============================] - 0s 592us/step - loss: 0.1315 - accuracy: 0.9694 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 12/100
# 222/222 [==============================] - 0s 638us/step - loss: 0.1448 - accuracy: 0.9667 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 13/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.1284 - accuracy: 0.9721 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 14/100
# 222/222 [==============================] - 0s 596us/step - loss: 0.0656 - accuracy: 0.9775 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 15/100
# 222/222 [==============================] - 0s 602us/step - loss: 0.1006 - accuracy: 0.9748 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 16/100
# 222/222 [==============================] - 0s 624us/step - loss: 0.0464 - accuracy: 0.9883 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 17/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0658 - accuracy: 0.9838 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 18/100
# 222/222 [==============================] - 0s 629us/step - loss: 0.0411 - accuracy: 0.9901 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 19/100
# 222/222 [==============================] - 0s 584us/step - loss: 0.0393 - accuracy: 0.9910 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 20/100
# 222/222 [==============================] - 0s 620us/step - loss: 0.0208 - accuracy: 0.9946 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 21/100
# 222/222 [==============================] - 0s 574us/step - loss: 0.0223 - accuracy: 0.9946 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 22/100
# 222/222 [==============================] - 0s 597us/step - loss: 0.0217 - accuracy: 0.9964 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 23/100
# 222/222 [==============================] - 0s 691us/step - loss: 0.0269 - accuracy: 0.9910 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 24/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0266 - accuracy: 0.9946 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 25/100
# 222/222 [==============================] - 0s 576us/step - loss: 0.0247 - accuracy: 0.9955 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 26/100
# 222/222 [==============================] - 0s 584us/step - loss: 0.0179 - accuracy: 0.9928 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 27/100
# 222/222 [==============================] - 0s 602us/step - loss: 0.0215 - accuracy: 0.9946 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 28/100
# 222/222 [==============================] - 0s 562us/step - loss: 0.0178 - accuracy: 0.9946 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 29/100
# 222/222 [==============================] - 0s 575us/step - loss: 0.0120 - accuracy: 0.9973 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 30/100
# 222/222 [==============================] - 0s 647us/step - loss: 0.0145 - accuracy: 0.9964 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 31/100
# 222/222 [==============================] - 0s 642us/step - loss: 0.0191 - accuracy: 0.9955 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 32/100
# 222/222 [==============================] - 0s 559us/step - loss: 0.0234 - accuracy: 0.9937 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 33/100
# 222/222 [==============================] - 0s 677us/step - loss: 0.0096 - accuracy: 0.9982 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 34/100
# 222/222 [==============================] - 0s 669us/step - loss: 0.0102 - accuracy: 0.9982 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 35/100
# 222/222 [==============================] - 0s 611us/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 36/100
# 222/222 [==============================] - 0s 571us/step - loss: 0.0060 - accuracy: 0.9991 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 37/100
# 222/222 [==============================] - 0s 593us/step - loss: 0.0243 - accuracy: 0.9973 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 38/100
# 222/222 [==============================] - 0s 638us/step - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 39/100
# 222/222 [==============================] - 0s 562us/step - loss: 0.0115 - accuracy: 0.9973 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 40/100
# 222/222 [==============================] - 0s 562us/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 41/100
# 222/222 [==============================] - 0s 598us/step - loss: 0.0062 - accuracy: 0.9991 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 42/100
# 222/222 [==============================] - 0s 619us/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 43/100
# 222/222 [==============================] - 0s 593us/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 44/100
# 222/222 [==============================] - 0s 579us/step - loss: 0.0079 - accuracy: 0.9982 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 45/100
# 222/222 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000 - 0s 633us/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 46/100
# 222/222 [==============================] - 0s 556us/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 47/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0096 - accuracy: 0.9982 - val_loss: 9.7796e-04 - val_accuracy: 1.0000
# Epoch 48/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 9.9079e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 222/222 [==============================] - 0s 629us/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 50/100
# 222/222 [==============================] - 0s 580us/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 9.4572e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 222/222 [==============================] - 0s 665us/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 8.1360e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 222/222 [==============================] - 0s 606us/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 8.6719e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 222/222 [==============================] - 0s 598us/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 6.7742e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 222/222 [==============================] - 0s 580us/step - loss: 0.0132 - accuracy: 0.9982 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 55/100
# 222/222 [==============================] - 0s 613us/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 56/100
# 222/222 [==============================] - 0s 624us/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 5.9271e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 222/222 [==============================] - 0s 593us/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 58/100
# 222/222 [==============================] - 0s 641us/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 8.6296e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 222/222 [==============================] - 0s 600us/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 5.9893e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 222/222 [==============================] - 0s 683us/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 4.6655e-04 - val_accuracy: 1.0000
# Epoch 61/100
# 222/222 [==============================] - 0s 629us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 4.7842e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 222/222 [==============================] - 0s 633us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.6276e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 222/222 [==============================] - 0s 642us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.2784e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 222/222 [==============================] - 0s 602us/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.2107e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 222/222 [==============================] - 0s 598us/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 4.5541e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 222/222 [==============================] - 0s 648us/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 9.5396e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 222/222 [==============================] - 0s 672us/step - loss: 0.0075 - accuracy: 0.9991 - val_loss: 5.8410e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 222/222 [==============================] - 0s 593us/step - loss: 8.8942e-04 - accuracy: 1.0000 - val_loss: 5.0472e-04 - val_accuracy: 1.0000
# Epoch 69/100
# 222/222 [==============================] - 0s 586us/step - loss: 0.0061 - accuracy: 0.9991 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 70/100
# 222/222 [==============================] - 0s 678us/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 71/100
# 222/222 [==============================] - 0s 775us/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 6.8001e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 222/222 [==============================] - 0s 705us/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 4.6586e-04 - val_accuracy: 1.0000
# Epoch 73/100
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 5.7291e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 222/222 [==============================] - 0s 732us/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 5.9161e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 222/222 [==============================] - 0s 624us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.0203e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 222/222 [==============================] - 0s 683us/step - loss: 0.0049 - accuracy: 0.9991 - val_loss: 9.1784e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 222/222 [==============================] - 0s 705us/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 78/100
# 222/222 [==============================] - 0s 613us/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 6.9795e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 222/222 [==============================] - 0s 656us/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 80/100
# 222/222 [==============================] - 0s 632us/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 8.2282e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 222/222 [==============================] - 0s 629us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 5.6316e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 222/222 [==============================] - 0s 624us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 4.4403e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.9248e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 222/222 [==============================] - 0s 593us/step - loss: 7.9561e-04 - accuracy: 1.0000 - val_loss: 3.5589e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 222/222 [==============================] - 0s 611us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5355e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 222/222 [==============================] - 0s 615us/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 87/100
# 222/222 [==============================] - 0s 658us/step - loss: 0.0061 - accuracy: 0.9964 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 88/100
# 222/222 [==============================] - 0s 580us/step - loss: 0.0026 - accuracy: 0.9982 - val_loss: 6.4486e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 222/222 [==============================] - 0s 626us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.7259e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.9738e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 222/222 [==============================] - 0s 626us/step - loss: 9.4571e-04 - accuracy: 1.0000 - val_loss: 2.3769e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 222/222 [==============================] - 0s 595us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.7545e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 222/222 [==============================] - 0s 642us/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 2.3400e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 222/222 [==============================] - 0s 589us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.3369e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 222/222 [==============================] - 0s 687us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.2392e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 222/222 [==============================] - 0s 606us/step - loss: 9.2881e-04 - accuracy: 1.0000 - val_loss: 3.3599e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 222/222 [==============================] - 0s 602us/step - loss: 5.8308e-04 - accuracy: 1.0000 - val_loss: 3.7367e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 222/222 [==============================] - 0s 597us/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 2.8418e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 222/222 [==============================] - 0s 593us/step - loss: 0.0070 - accuracy: 0.9991 - val_loss: 7.3175e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 222/222 [==============================] - 0s 592us/step - loss: 9.7186e-04 - accuracy: 1.0000 - val_loss: 5.3950e-04 - val_accuracy: 1.0000

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.0001187960006063804
# Test accuracy: 1.0

# %%
print("AF coefficients (weights) {}".format(diffact.get_weights()))
# Out:
# AF coefficients (weights) [1.6777613, -0.21792224, -1.3766757]

# %%
# %tensorboard --logdir banklogs/smallk1k0 --port=6030
# Out:
# Reusing TensorBoard on port 6030 (pid 21024), started 0:00:58 ago. (Use '!kill 21024' to kill it.)
#       <iframe id="tensorboard-frame-a04e640a24f1cdb2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a04e640a24f1cdb2");
#           const url = new URL("/", window.location);
#           const port = 6030;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
df.describe()
# Out:
#           variance     skewness     curtosis      entropy        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000
